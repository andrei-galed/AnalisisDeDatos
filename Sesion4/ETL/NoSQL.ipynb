# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]m1/2 [pymongo]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
#definir URL de conexion 
uri = 'mongodb+srv://andreigaled3:1234@cluster0.qdxwmr6.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

#crear una nueva instancoa de clinete mongo 
client = MongoClient(uri,server_api=ServerApi('1'))

try:
    #enviar un comando ping al servidor 
    client.admin.command('ping')
    print('ping exitoso')

except Exception as e: 
    print(e)
# Out:
# ping exitoso
